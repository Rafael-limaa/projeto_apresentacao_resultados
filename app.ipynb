# %%
import pandas as pd

# %%
csv_file = 'student_habits_performance.csv'
df = pd.read_csv(csv_file)

# %%
df = df.rename(columns={"student_id": "ID do Estudante",
    "age": "Idade",
    "gender": "Gênero",
    "study_hours_per_day": "Horas de Estudo por Dia",
    "social_media_hours": "Horas em Mídias Sociais",
    "netflix_hours": "Horas no Netflix",
    "part_time_job": "Trabalho de Meio Período",
    "attendance_percentage": "Percentual de Frequência",
    "sleep_hours": "Horas de Sono",
    "diet_quality": "Qualidade da Dieta",
    "exercise_frequency": "Frequência de Exercícios",
    "parental_education_level": "Escolaridade dos Pais",
    "internet_quality": "Qualidade da Internet",
    "mental_health_rating": "Avaliação de Saúde Mental",
    "extracurricular_participation": "Participação em Atividades Extracurriculares",
    "exam_score": "Nota da Prova"})

# %%
df.describe()
# Out:
#            Idade  Horas de Estudo por Dia  Horas em Mídias Sociais  \
# count  1000.0000               1000.00000              1000.000000
# mean     20.4980                  3.55010                 2.505500
# std       2.3081                  1.46889                 1.172422
# min      17.0000                  0.00000                 0.000000
# 25%      18.7500                  2.60000                 1.700000
# 50%      20.0000                  3.50000                 2.500000
# 75%      23.0000                  4.50000                 3.300000
# max      24.0000                  8.30000                 7.200000
#
#        Horas no Netflix  Percentual de Frequência  Horas de Sono  \
# count       1000.000000               1000.000000    1000.000000
# mean           1.819700                 84.131700       6.470100
# std            1.075118                  9.399246       1.226377
# min            0.000000                 56.000000       3.200000
# 25%            1.000000                 78.000000       5.600000
# 50%            1.800000                 84.400000       6.500000
# 75%            2.525000                 91.025000       7.300000
# max            5.400000                100.000000      10.000000
#
#        Frequência de Exercícios  Avaliação de Saúde Mental  Nota da Prova
# count               1000.000000                1000.000000    1000.000000
# mean                   3.042000                   5.438000      69.601500
# std                    2.025423                   2.847501      16.888564
# min                    0.000000                   1.000000      18.400000
# 25%                    1.000000                   3.000000      58.475000
# 50%                    3.000000                   5.000000      70.500000
# 75%                    5.000000                   8.000000      81.325000
# max                    6.000000                  10.000000     100.000000

# %%
df_number = df.select_dtypes(include='number')
df_number.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_26f04_row0_col0, #T_26f04_row1_col1, #T_26f04_row2_col2, #T_26f04_row3_col3, #T_26f04_row4_col4, #T_26f04_row5_col5, #T_26f04_row6_col6, #T_26f04_row7_col7, #T_26f04_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col1, #T_26f04_row0_col6, #T_26f04_row2_col0, #T_26f04_row8_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col3, #T_26f04_row4_col3, #T_26f04_row5_col3, #T_26f04_row8_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col4, #T_26f04_row0_col7, #T_26f04_row1_col5, #T_26f04_row2_col6, #T_26f04_row3_col1, #T_26f04_row3_col8, #T_26f04_row5_col1, #T_26f04_row6_col1, #T_26f04_row7_col0, #T_26f04_row8_col2, #T_26f04_row8_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col5, #T_26f04_row2_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_26f04_row0_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col0, #T_26f04_row2_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col4, #T_26f04_row3_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col7, #T_26f04_row3_col0, #T_26f04_row4_col5, #T_26f04_row6_col0, #T_26f04_row6_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_26f04_row1_col8 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_26f04_row2_col3, #T_26f04_row5_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_26f04_row2_col5, #T_26f04_row2_col7, #T_26f04_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_26f04_row2_col8, #T_26f04_row7_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_26f04_row3_col2, #T_26f04_row7_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_26f04_row3_col4, #T_26f04_row7_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_26f04_row3_col5, #T_26f04_row4_col7, #T_26f04_row7_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_26f04_row3_col6, #T_26f04_row4_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_26f04_row4_col0, #T_26f04_row6_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_26f04_row4_col1, #T_26f04_row5_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_26f04_row4_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_26f04_row4_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_26f04_row5_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_26f04_row5_col4, #T_26f04_row5_col7, #T_26f04_row7_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_26f04_row5_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_26f04_row6_col2, #T_26f04_row8_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_26f04_row6_col3, #T_26f04_row7_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_26f04_row6_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_26f04_row7_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_26f04_row8_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_26f04_row8_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_26f04_row8_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# </style>
# <table id="T_26f04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26f04_level0_col0" class="col_heading level0 col0" >Idade</th>
#       <th id="T_26f04_level0_col1" class="col_heading level0 col1" >Horas de Estudo por Dia</th>
#       <th id="T_26f04_level0_col2" class="col_heading level0 col2" >Horas em Mídias Sociais</th>
#       <th id="T_26f04_level0_col3" class="col_heading level0 col3" >Horas no Netflix</th>
#       <th id="T_26f04_level0_col4" class="col_heading level0 col4" >Percentual de Frequência</th>
#       <th id="T_26f04_level0_col5" class="col_heading level0 col5" >Horas de Sono</th>
#       <th id="T_26f04_level0_col6" class="col_heading level0 col6" >Frequência de Exercícios</th>
#       <th id="T_26f04_level0_col7" class="col_heading level0 col7" >Avaliação de Saúde Mental</th>
#       <th id="T_26f04_level0_col8" class="col_heading level0 col8" >Nota da Prova</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26f04_level0_row0" class="row_heading level0 row0" >Idade</th>
#       <td id="T_26f04_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_26f04_row0_col1" class="data row0 col1" >0.003971</td>
#       <td id="T_26f04_row0_col2" class="data row0 col2" >-0.009151</td>
#       <td id="T_26f04_row0_col3" class="data row0 col3" >-0.001174</td>
#       <td id="T_26f04_row0_col4" class="data row0 col4" >-0.026055</td>
#       <td id="T_26f04_row0_col5" class="data row0 col5" >0.037482</td>
#       <td id="T_26f04_row0_col6" class="data row0 col6" >-0.003836</td>
#       <td id="T_26f04_row0_col7" class="data row0 col7" >-0.045101</td>
#       <td id="T_26f04_row0_col8" class="data row0 col8" >-0.008907</td>
#     </tr>
#     <tr>
#       <th id="T_26f04_level0_row1" class="row_heading level0 row1" >Horas de Estudo por Dia</th>
#       <td id="T_26f04_row1_col0" class="data row1 col0" >0.003971</td>
#       <td id="T_26f04_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_26f04_row1_col2" class="data row1 col2" >0.020282</td>
#       <td id="T_26f04_row1_col3" class="data row1 col3" >-0.031158</td>
#       <td id="T_26f04_row1_col4" class="data row1 col4" >0.026264</td>
#       <td id="T_26f04_row1_col5" class="data row1 col5" >-0.027757</td>
#       <td id="T_26f04_row1_col6" class="data row1 col6" >-0.028701</td>
#       <td id="T_26f04_row1_col7" class="data row1 col7" >-0.003768</td>
#       <td id="T_26f04_row1_col8" class="data row1 col8" >0.825419</td>
#     </tr>
#     <tr>
#       <th id="T_26f04_level0_row2" class="row_heading level0 row2" >Horas em Mídias Sociais</th>
#       <td id="T_26f04_row2_col0" class="data row2 col0" >-0.009151</td>
#       <td id="T_26f04_row2_col1" class="data row2 col1" >0.020282</td>
#       <td id="T_26f04_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_26f04_row2_col3" class="data row2 col3" >0.011477</td>
#       <td id="T_26f04_row2_col4" class="data row2 col4" >0.040479</td>
#       <td id="T_26f04_row2_col5" class="data row2 col5" >0.018236</td>
#       <td id="T_26f04_row2_col6" class="data row2 col6" >-0.037319</td>
#       <td id="T_26f04_row2_col7" class="data row2 col7" >0.001496</td>
#       <td id="T_26f04_row2_col8" class="data row2 col8" >-0.166733</td>
#     </tr>
#     <tr>
#       <th id="T_26f04_level0_row3" class="row_heading level0 row3" >Horas no Netflix</th>
#       <td id="T_26f04_row3_col0" class="data row3 col0" >-0.001174</td>
#       <td id="T_26f04_row3_col1" class="data row3 col1" >-0.031158</td>
#       <td id="T_26f04_row3_col2" class="data row3 col2" >0.011477</td>
#       <td id="T_26f04_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_26f04_row3_col4" class="data row3 col4" >-0.002092</td>
#       <td id="T_26f04_row3_col5" class="data row3 col5" >-0.000935</td>
#       <td id="T_26f04_row3_col6" class="data row3 col6" >-0.006448</td>
#       <td id="T_26f04_row3_col7" class="data row3 col7" >0.008034</td>
#       <td id="T_26f04_row3_col8" class="data row3 col8" >-0.171779</td>
#     </tr>
#     <tr>
#       <th id="T_26f04_level0_row4" class="row_heading level0 row4" >Percentual de Frequência</th>
#       <td id="T_26f04_row4_col0" class="data row4 col0" >-0.026055</td>
#       <td id="T_26f04_row4_col1" class="data row4 col1" >0.026264</td>
#       <td id="T_26f04_row4_col2" class="data row4 col2" >0.040479</td>
#       <td id="T_26f04_row4_col3" class="data row4 col3" >-0.002092</td>
#       <td id="T_26f04_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_26f04_row4_col5" class="data row4 col5" >0.013756</td>
#       <td id="T_26f04_row4_col6" class="data row4 col6" >-0.007857</td>
#       <td id="T_26f04_row4_co
